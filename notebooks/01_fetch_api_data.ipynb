# %%
import pandas as pd
import os
path = "../data/raw/"

df_life = pd.read_csv(path + "life_expectancy.csv")
df_san = pd.read_csv(path + "sanitation.csv")
df_poll = pd.read_csv(path + "pollution.csv")
df_mort = pd.read_csv(path + "mortality_u5.csv")
df_exp = pd.read_csv(path + "health_expenditure.csv")
df_gdp = pd.read_csv(path + "gdp_per_capita.csv")
obesity_file = os.path.join(path, "obesity.csv")
if os.path.exists(obesity_file):
	df_obesity = pd.read_csv(obesity_file)
else:
	df_obesity = pd.DataFrame()
df_life.head()
# Out:
#                           country country_code       indicator  \
# 0     Africa Eastern and Southern           ZH  SP.DYN.LE00.IN
# 1      Africa Western and Central           ZI  SP.DYN.LE00.IN
# 2                      Arab World           1A  SP.DYN.LE00.IN
# 3          Caribbean small states           S3  SP.DYN.LE00.IN
# 4  Central Europe and the Baltics           B8  SP.DYN.LE00.IN
#
#                             indicator_name  year      value
# 0  Life expectancy at birth, total (years)  2020  63.766484
# 1  Life expectancy at birth, total (years)  2020  57.364425
# 2  Life expectancy at birth, total (years)  2020  70.726559
# 3  Life expectancy at birth, total (years)  2020  71.939436
# 4  Life expectancy at birth, total (years)  2020  76.016270
